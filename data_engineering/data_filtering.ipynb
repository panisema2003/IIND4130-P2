# %%
import pandas as pd

# %%
cleaned_data = pd.read_csv("../data/clean_icfes_data_cesar.csv")
df = cleaned_data.copy()
df
# Out:
#        periodo estu_tipodocumento  estu_consecutivo cole_area_ubicacion  \
# 0        20224                 TI  SB11202240346555              URBANO
# 1        20224                 TI  SB11202240587156              URBANO
# 2        20224                 TI  SB11202240047096              URBANO
# 3        20224                 CC  SB11202240362450              URBANO
# 4        20224                 TI  SB11202240373694               RURAL
# ...        ...                ...               ...                 ...
# 77570    20162                 TI  SB11201620486055              URBANO
# 77571    20162                 TI  SB11201620525906              URBANO
# 77572    20142                 TI  SB11201420185350               RURAL
# 77573    20142                 TI  SB11201420586016              URBANO
# 77574    20194                 TI  SB11201940513265              URBANO
#
#       cole_bilingue cole_calendario      cole_caracter  \
# ...

# %%
filtered_df = df[["periodo", "cole_area_ubicacion", "cole_bilingue", "cole_calendario", 
                  "cole_caracter", "cole_cod_dane_establecimiento", "cole_cod_dane_sede", 
                  "cole_cod_mcpio_ubi", "cole_genero", "cole_jornada", "cole_naturaleza",
                  "estu_cod_reside_mcpio", "estu_depto_reside", "estu_genero", "estu_mcpio_reside",
                  "estu_nacionalidad", "fami_cuartos_hogar", "fami_educacionmadre", "fami_educacionpadre", 
                  "fami_estratovivienda", "fami_personashogar", "fami_tieneautomovil", 
                  ]] # TODO: see if we add names or not, I think they're linear combinations ... Also, sede principal is redundant right?,
                    # also i think depto reside is cap, remove estu_estadoinvestigacion != publicar?
                    # also, what do we do if some features might be null, tuhs, user might have them null hmmmmmmmmm
